# %% [markdown]
# Task 1 A – Rule-Based Programming
#
#     • Write a Python program to check if a number is even or odd
#
# Task 1 B – ML-Based Classification
#
#     • Use the below code to simulate ML-based even/odd classification

# %%
# Task 1 A
a = 3
#check odd or not
if a % 2 != 0:
    print("The number is odd.")
