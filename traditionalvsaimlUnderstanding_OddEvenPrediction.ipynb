# %% [markdown]
# Task 1 A – Rule-Based Programming
#
#     • Write a Python program to check if a number is even or odd
#
# Task 1 B – ML-Based Classification

# %%
# Task 1 A
a = 3
#check odd or not
if a % 2 != 0:
    print("The number is odd.")
# Out:
# The number is odd.

# %%
# Task 1 B
import pandas as pd

data= {
    "numbers": [1, 2, 3, 4, 5],
    "eventOrNot": [1, 0, 1, 0, 1] # 1=odd, 0=even
}
df = pd.DataFrame(data)
#view the data
print(df)
# Out:
#    numbers  eventOrNot
# 0        1           1
# 1        2           0
# 2        3           1
# 3        4           0
# 4        5           1

# %%
# sperate input and output for train the model

input_data = df[["numbers"]]
output_data = df["eventOrNot"]
print("Input Data:\n", input_data)
print("Output Data:\n", output_data)
# Out:
# Input Data:
#     numbers
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# Output Data:
#  0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: eventOrNot, dtype: int64

# %%
#train the model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(input_data, output_data)
print("Model trained successfully.")
# Out:
# Model trained successfully.

# %%
#predicting new data
test_data = pd.DataFrame({"numbers": [6, 7, 8]})
print("Test Data:\n", test_data)
predictions = model.predict(test_data)
print("Predictions:\n", predictions)
# Out:
# Test Data:
#     numbers
# 0        6
# 1        7
# 2        8
# Predictions:
#  [1 1 1]
